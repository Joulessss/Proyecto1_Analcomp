# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/danielmorantes/PythonP/Analítica_Comp_Uniandes/Proyecto1/Proyecto1_Analcomp/DataAWS.csv')
data["periodo"][0]
valor = data["periodo"][0]+data["periodo"][1]
valor
# Out:
# np.int64(40294)

# %%
#Initial view of the data
raw_data = pd.read_csv('/Users/danielmorantes/PythonP/Analítica_Comp_Uniandes/Proyecto1/Proyecto1_Analcomp/DataAWS.csv')
raw_data.head()
# Out:
#    periodo estu_tipodocumento  estu_consecutivo cole_area_ubicacion  \
# 0    20162                 TI  SB11201620604627              URBANO
# 1    20132                 TI  SB11201320007175              URBANO
# 2    20102                 CC  SB11201020409042              URBANO
# 3    20142                 TI  SB11201420116599               RURAL
# 4    20152                 TI  SB11201520349379              URBANO
#
#   cole_bilingue cole_calendario      cole_caracter  \
# 0             N               A  TÉCNICO/ACADÉMICO
# 1             N               A  TÉCNICO/ACADÉMICO
# 2             N               A            TÉCNICO
# 3             N               A  TÉCNICO/ACADÉMICO
# 4             N               A            TÉCNICO
#
#    cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# 0                   115238000698        115238000698
# 1                   315762000076        315762000076
# 2                   115790000031        115790000031
# 3                   215759000524        215759000524
# 4                   115835000283        115835000283
#
#    cole_cod_depto_ubicacion  ...  fami_tienecomputador  fami_tieneinternet  \
# 0                        15  ...                   NaN                 NaN
# 1                        15  ...                    Si                  Si
# 2                        15  ...                    Si                  Si
# 3                        15  ...                    Si                  No
# 4                        15  ...                    No                  No
#
#   fami_tienelavadora desemp_ingles punt_ingles punt_matematicas  \
# 0                NaN            A2       61.00            59.00
# 1                 No            A1       43.00            52.00
# 2                 Si            A-       38.53            45.38
# 3                 No            A1       52.00            55.00
# 4                 Si            A1       55.00            52.00
#
#   punt_sociales_ciudadanas punt_c_naturales punt_lectura_critica punt_global
# 0                     63.0             57.0                 56.0       295.0
# 1                      NaN              NaN                  NaN         NaN
# 2                      NaN              NaN                  NaN         NaN
# 3                     54.0             60.0                 54.0       277.0
# 4                     50.0             53.0                 47.0       254.0
#
# [5 rows x 51 columns]

# %%
raw_data.shape
# Out:
# (215234, 51)

# %%
#Colums names
raw_data.columns
# Out:
# Index(['periodo', 'estu_tipodocumento', 'estu_consecutivo',
#        'cole_area_ubicacion', 'cole_bilingue', 'cole_calendario',
#        'cole_caracter', 'cole_cod_dane_establecimiento', 'cole_cod_dane_sede',
#        'cole_cod_depto_ubicacion', 'cole_cod_mcpio_ubicacion',
#        'cole_codigo_icfes', 'cole_depto_ubicacion', 'cole_genero',
#        'cole_jornada', 'cole_mcpio_ubicacion', 'cole_naturaleza',
#        'cole_nombre_establecimiento', 'cole_nombre_sede',
#        'cole_sede_principal', 'estu_cod_depto_presentacion',
#        'estu_cod_mcpio_presentacion', 'estu_cod_reside_depto',
#        'estu_cod_reside_mcpio', 'estu_depto_presentacion', 'estu_depto_reside',
#        'estu_estadoinvestigacion', 'estu_estudiante', 'estu_fechanacimiento',
#        'estu_genero', 'estu_mcpio_presentacion', 'estu_mcpio_reside',
#        'estu_nacionalidad', 'estu_pais_reside', 'estu_privado_libertad',
#        'fami_cuartoshogar', 'fami_educacionmadre', 'fami_educacionpadre',
#        'fami_estratovivienda', 'fami_personashogar', 'fami_tieneautomovil',
#        'fami_tienecomputador', 'fami_tieneinternet', 'fami_tienelavadora',
#        'desemp_ingles', 'punt_ingles', 'punt_matematicas',
#        'punt_sociales_ciudadanas', 'punt_c_naturales', 'punt_lectura_critica',
#        'punt_global'],
#       dtype='object')

# %%
#Nan values
raw_data.isna().sum()
# Out:
# periodo                              0
# estu_tipodocumento                   0
# estu_consecutivo                     0
# cole_area_ubicacion                 80
# cole_bilingue                    17277
# cole_calendario                     49
# cole_caracter                      980
# cole_cod_dane_establecimiento        0
# cole_cod_dane_sede                   0
# cole_cod_depto_ubicacion             0
# cole_cod_mcpio_ubicacion             0
# cole_codigo_icfes                 1616
# cole_depto_ubicacion                 0
# cole_genero                          0
# cole_jornada                         0
# cole_mcpio_ubicacion                 0
# cole_naturaleza                      0
# cole_nombre_establecimiento          0
# cole_nombre_sede                     0
# cole_sede_principal                  0
# estu_cod_depto_presentacion          0
# estu_cod_mcpio_presentacion          0
# estu_cod_reside_depto             1234
# estu_cod_reside_mcpio             1234
# estu_depto_presentacion              0
# estu_depto_reside                 1234
# estu_estadoinvestigacion             0
# estu_estudiante                      0
# estu_fechanacimiento                 0
# estu_genero                        121
# estu_mcpio_presentacion              0
# estu_mcpio_reside                 1234
# estu_nacionalidad                    0
# estu_pais_reside                     0
# estu_privado_libertad                0
# fami_cuartoshogar                 3530
# fami_educacionmadre               7424
# fami_educacionpadre               7459
# fami_estratovivienda              5522
# fami_personashogar                3573
# fami_tieneautomovil               3561
# fami_tienecomputador              5515
# fami_tieneinternet                5067
# fami_tienelavadora                3487
# desemp_ingles                       33
# punt_ingles                          3
# punt_matematicas                     0
# punt_sociales_ciudadanas         83150
# punt_c_naturales                 83150
# punt_lectura_critica             83150
# punt_global                      83150
# dtype: int64

# %%
raw_data.isna().sum(axis=0)/raw_data.shape[0]*100
# Out:
# periodo                           0.000000
# estu_tipodocumento                0.000000
# estu_consecutivo                  0.000000
# cole_area_ubicacion               0.037169
# cole_bilingue                     8.027078
# cole_calendario                   0.022766
# cole_caracter                     0.455318
# cole_cod_dane_establecimiento     0.000000
# cole_cod_dane_sede                0.000000
# cole_cod_depto_ubicacion          0.000000
# cole_cod_mcpio_ubicacion          0.000000
# cole_codigo_icfes                 0.750811
# cole_depto_ubicacion              0.000000
# cole_genero                       0.000000
# cole_jornada                      0.000000
# cole_mcpio_ubicacion              0.000000
# cole_naturaleza                   0.000000
# cole_nombre_establecimiento       0.000000
# cole_nombre_sede                  0.000000
# cole_sede_principal               0.000000
# estu_cod_depto_presentacion       0.000000
# estu_cod_mcpio_presentacion       0.000000
# estu_cod_reside_depto             0.573329
# estu_cod_reside_mcpio             0.573329
# estu_depto_presentacion           0.000000
# estu_depto_reside                 0.573329
# estu_estadoinvestigacion          0.000000
# estu_estudiante                   0.000000
# estu_fechanacimiento              0.000000
# estu_genero                       0.056218
# estu_mcpio_presentacion           0.000000
# estu_mcpio_reside                 0.573329
# estu_nacionalidad                 0.000000
# estu_pais_reside                  0.000000
# estu_privado_libertad             0.000000
# fami_cuartoshogar                 1.640075
# fami_educacionmadre               3.449269
# fami_educacionpadre               3.465531
# fami_estratovivienda              2.565580
# fami_personashogar                1.660054
# fami_tieneautomovil               1.654478
# fami_tienecomputador              2.562328
# fami_tieneinternet                2.354182
# fami_tienelavadora                1.620097
# desemp_ingles                     0.015332
# punt_ingles                       0.001394
# punt_matematicas                  0.000000
# punt_sociales_ciudadanas         38.632372
# punt_c_naturales                 38.632372
# punt_lectura_critica             38.632372
# punt_global                      38.632372
# dtype: float64

# %%
raw_data["periodo"].unique()
# Out:
# array([20162, 20132, 20102, 20142, 20152, 20172, 20194, 20122, 20112,
#        20141, 20224, 20111, 20201, 20101, 20151, 20121, 20131, 20181,
#        20211, 20221])

# %%
cols = ["punt_lectura_critica","punt_c_naturales","punt_sociales_ciudadanas","punt_ingles","punt_matematicas","punt_global"]
raw_data.groupby("periodo")[cols].count()
# Out:
#          punt_lectura_critica  punt_c_naturales  punt_sociales_ciudadanas  \
# periodo
# 20101                       0                 0                         0
# 20102                       0                 0                         0
# 20111                       0                 0                         0
# 20112                       0                 0                         0
# 20121                       0                 0                         0
# 20122                       0                 0                         0
# 20131                       0                 0                         0
# 20132                       0                 0                         0
# 20141                       0                 0                         0
# 20142                   17325             17325                     17325
# 20151                     299               299                       299
# 20152                   16538             16538                     16538
# 20162                   16840             16840                     16840
# 20172                   16872             16872                     16872
# 20181                      87                87                        87
# 20194                   33474             33474                     33474
# 20201                      94                94                        94
# 20211                      65                65                        65
# 20221                     120               120                       120
# 20224                   30370             30370                     30370
#
#          punt_ingles  punt_matematicas  punt_global
# periodo
# 20101            658               658            0
# 20102          20202             20202            0
# 20111            487               487            0
# 20112          20235             20235            0
# 20121            460               460            0
# 20122          22352             22352            0
# 20131            340               340            0
# 20132          18109             18109            0
# 20141            307               307            0
# 20142          17325             17325        17325
# 20151            299               299          299
# 20152          16538             16538        16538
# 20162          16840             16840        16840
# 20172          16872             16872        16872
# 20181             87                87           87
# 20194          33474             33474        33474
# 20201             94                94           94
# 20211             64                65           65
# 20221            120               120          120
# 20224          30368             30370        30370

# %% [markdown]
# no hay registros para puntajes antes de 20141, por lo que se eliminan estos registros, no son relevantes ni aportan valor en los análisis.

# %%
raw_data1 = raw_data[raw_data["periodo"] >= 20142]
raw_data1.shape
# Out:
# (132084, 51)

# %%
raw_data1.groupby("periodo")[cols].count()
# Out:
#          punt_lectura_critica  punt_c_naturales  punt_sociales_ciudadanas  \
# periodo
# 20142                   17325             17325                     17325
# 20151                     299               299                       299
# 20152                   16538             16538                     16538
# 20162                   16840             16840                     16840
# 20172                   16872             16872                     16872
# 20181                      87                87                        87
# 20194                   33474             33474                     33474
# 20201                      94                94                        94
# 20211                      65                65                        65
# 20221                     120               120                       120
# 20224                   30370             30370                     30370
#
#          punt_ingles  punt_matematicas  punt_global
# periodo
# 20142          17325             17325        17325
# 20151            299               299          299
# 20152          16538             16538        16538
# 20162          16840             16840        16840
# 20172          16872             16872        16872
# 20181             87                87           87
# 20194          33474             33474        33474
# 20201             94                94           94
# 20211             64                65           65
# 20221            120               120          120
# 20224          30368             30370        30370

# %%
raw_data1.isna().sum(axis=0)/raw_data.shape[0]*100
# Out:
# periodo                          0.000000
# estu_tipodocumento               0.000000
# estu_consecutivo                 0.000000
# cole_area_ubicacion              0.000000
# cole_bilingue                    8.750492
# cole_calendario                  0.000000
# cole_caracter                    0.602647
# cole_cod_dane_establecimiento    0.000000
# cole_cod_dane_sede               0.000000
# cole_cod_depto_ubicacion         0.000000
# cole_cod_mcpio_ubicacion         0.000000
# cole_codigo_icfes                0.000000
# cole_depto_ubicacion             0.000000
# cole_genero                      0.000000
# cole_jornada                     0.000000
# cole_mcpio_ubicacion             0.000000
# cole_naturaleza                  0.000000
# cole_nombre_establecimiento      0.000000
# cole_nombre_sede                 0.000000
# cole_sede_principal              0.000000
# estu_cod_depto_presentacion      0.000000
# estu_cod_mcpio_presentacion      0.000000
# estu_cod_reside_depto            0.046940
# estu_cod_reside_mcpio            0.046940
# estu_depto_presentacion          0.000000
# estu_depto_reside                0.046940
# estu_estadoinvestigacion         0.000000
# estu_estudiante                  0.000000
# estu_fechanacimiento             0.000000
# estu_genero                      0.088580
# estu_mcpio_presentacion          0.000000
# estu_mcpio_reside                0.046940
# estu_nacionalidad                0.000000
# estu_pais_reside                 0.000000
# estu_privado_libertad            0.000000
# fami_cuartoshogar                1.877593
# fami_educacionmadre              2.886042
# fami_educacionpadre              2.885285
# fami_estratovivienda             3.231277
# fami_personashogar               1.870779
# fami_tieneautomovil              1.861694
# fami_tienecomputador             1.801127
# fami_tieneinternet               2.990521
# fami_tienelavadora               1.806426
# desemp_ingles                    0.002271
# punt_ingles                      0.002271
# punt_matematicas                 0.000000
# punt_sociales_ciudadanas         0.000000
# punt_c_naturales                 0.000000
# punt_lectura_critica             0.000000
# punt_global                      0.000000
# dtype: float64

# %%
raw_data1.describe()
# Out:
#              periodo  cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# count  132084.000000                   1.320840e+05        1.320840e+05
# mean    20181.860415                   1.915744e+11        1.937988e+11
# std        28.855334                   9.073463e+10        9.180739e+10
# min     20142.000000                   1.150010e+11        1.150010e+11
# 25%     20152.000000                   1.153320e+11        1.153670e+11
# 50%     20172.000000                   1.158040e+11        1.158140e+11
# 75%     20194.000000                   3.150010e+11        3.150010e+11
# max     20224.000000                   4.158390e+11        5.154690e+11
#
#        cole_cod_depto_ubicacion  cole_cod_mcpio_ubicacion  cole_codigo_icfes  \
# count                  132084.0             132084.000000      132084.000000
# mean                       15.0              15410.978870      131007.155575
# std                         0.0                288.718222      210381.867718
# min                        15.0              15001.000000        4747.000000
# 25%                        15.0              15176.000000        5595.000000
# 50%                        15.0              15407.000000       47316.000000
# 75%                        15.0              15740.000000      132019.000000
# max                        15.0              15897.000000      783480.000000
#
#        estu_cod_depto_presentacion  estu_cod_mcpio_presentacion  \
# count                132084.000000                132084.000000
# mean                     15.738242                 16105.002771
# std                       6.614105                  6610.937236
# min                       5.000000                  5001.000000
# 25%                      15.000000                 15176.000000
# 50%                      15.000000                 15299.000000
# 75%                      15.000000                 15753.000000
# max                      99.000000                 99001.000000
#
#        estu_cod_reside_depto  estu_cod_reside_mcpio    punt_ingles  \
# count          132022.000000          132022.000000  132081.000000
# mean               15.102581           15506.584986      51.659785
# std                 2.192938            2210.896201      10.940840
# min                 5.000000            5001.000000       0.000000
# 25%                15.000000           15176.000000      44.000000
# 50%                15.000000           15403.000000      51.000000
# 75%                15.000000           15720.000000      58.000000
# max                85.000000           85225.000000     100.000000
#
#        punt_matematicas  punt_sociales_ciudadanas  punt_c_naturales  \
# count     132084.000000             132084.000000     132084.000000
# mean          54.356743                 51.333053         52.838126
# std           11.219249                 11.095774          9.630691
# min            0.000000                  0.000000          0.000000
# 25%           47.000000                 43.000000         46.000000
# 50%           54.000000                 51.500000         53.000000
# 75%           62.000000                 59.000000         60.000000
# max          100.000000                100.000000        100.000000
#
#        punt_lectura_critica    punt_global
# count         132084.000000  132084.000000
# mean              53.735388     264.789104
# std                9.751058      46.214481
# min                0.000000       0.000000
# 25%               47.000000     231.000000
# 50%               54.000000     263.000000
# 75%               61.000000     297.000000
# max              100.000000     471.000000

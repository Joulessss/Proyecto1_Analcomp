# %% [markdown]
# ## Tarea 3 - Análsis de datos - Pregunta 2

# %% [markdown]
# librerias

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go      # figuras de bajo nivel (Dash-ready)
import plotly.express as px            # API de alto nivel
import plotly.figure_factory as ff     # distribuciones, dendrogramas
from plotly.subplots import make_subplots  # layouts multi-panel
import plotly.io as pio                # configuración global

# %%
df = pd.read_csv('../tarea2_limpieza/cleaned_data.csv')
df.shape
# Out:
# (100049, 16)

# %%
df.describe(include='all')
# Out:
#               periodo cole_area_ubicacion cole_bilingue      cole_caracter  \
# count   100049.000000              100049        100049             100049
# unique            NaN                   2             3                  5
# top               NaN              URBANO             N  TÉCNICO/ACADÉMICO
# freq              NaN               84547         90396              45502
# mean     20173.386251                 NaN           NaN                NaN
# std         27.041575                 NaN           NaN                NaN
# min      20142.000000                 NaN           NaN                NaN
# 25%      20152.000000                 NaN           NaN                NaN
# 50%      20162.000000                 NaN           NaN                NaN
# 75%      20194.000000                 NaN           NaN                NaN
# max      20224.000000                 NaN           NaN                NaN
#
# ...
